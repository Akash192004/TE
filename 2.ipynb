# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\System21\Downloads\StudentPerformance.csv")
df
# Out:
#     math score  reading score   writing score  placement score  \
# 0         79.0            70.0           79.0            100.0
# 1         77.0            64.0           68.0              NaN
# 2         21.0             NaN            NaN             87.0
# 3         75.0            60.0           60.0             99.0
# 4         72.0             NaN            NaN             94.0
# 5          NaN            61.0           69.0             97.0
# 6         60.0            64.0           72.0             86.0
# 7         20.0            60.0           72.0              NaN
# 8         77.0            80.0           63.0             77.0
# 9         72.0            78.0           78.0             75.0
# 10         NaN             NaN            NaN              NaN
# 11        70.0            72.0           74.0             95.0
# 12        61.0            71.0           67.0             81.0
# 13         NaN            71.0           77.0             81.0
# ...

# %%
df.isnull()
# Out:
#     math score  reading score   writing score  placement score  \
# 0        False           False          False            False
# 1        False           False          False             True
# 2        False            True           True            False
# 3        False           False          False            False
# 4        False            True           True            False
# 5         True           False          False            False
# 6        False           False          False            False
# 7        False           False          False             True
# 8        False           False          False            False
# 9        False           False          False            False
# 10        True            True           True             True
# 11       False           False          False            False
# 12       False           False          False            False
# 13        True           False          False            False
# ...

# %%
series=pd.isnull(df["math score"])
series
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# Name: math score, dtype: bool

# %%
series1=pd.notnull(df["math score"])
df[series1]
# Out:
#     math score  reading score   writing score  placement score  \
# 0         79.0            70.0           79.0            100.0
# 1         77.0            64.0           68.0              NaN
# 2         21.0             NaN            NaN             87.0
# 3         75.0            60.0           60.0             99.0
# 4         72.0             NaN            NaN             94.0
# 6         60.0            64.0           72.0             86.0
# 7         20.0            60.0           72.0              NaN
# 8         77.0            80.0           63.0             77.0
# 9         72.0            78.0           78.0             75.0
# 11        70.0            72.0           74.0             95.0
# 12        61.0            71.0           67.0             81.0
# 14        73.0             NaN           68.0             97.0
# 15        75.0            61.0           77.0            100.0
# 16        11.0            75.0           70.0              NaN
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['gender']= le.fit_transform(df['gender'])
newdf=df
newdf
# Out:
#     math score  reading score   writing score  placement score  \
# 0         79.0            70.0           79.0            100.0
# 1         77.0            64.0           68.0              NaN
# 2         21.0             NaN            NaN             87.0
# 3         75.0            60.0           60.0             99.0
# 4         72.0             NaN            NaN             94.0
# 5          NaN            61.0           69.0             97.0
# 6         60.0            64.0           72.0             86.0
# 7         20.0            60.0           72.0              NaN
# 8         77.0            80.0           63.0             77.0
# 9         72.0            78.0           78.0             75.0
# 10         NaN             NaN            NaN              NaN
# 11        70.0            72.0           74.0             95.0
# 12        61.0            71.0           67.0             81.0
# 13         NaN            71.0           77.0             81.0
# ...

# %%
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\System21\Downloads\StudentPerformance.csv")
col=['math_score','writing_score','placement_score']
df.boxplot(col)
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax=plt.subplots(figsize=(18,10))
ax.scatter(df['placement_score'],df['placement_offer_count'])
plt.show()

# %%
fig, ax=plt.subplots(figsize=(18,10))
ax.scatter(df['math_score'],df['placement_offer_count'])
plt.show()

# %%
fig, ax=plt.subplots(figsize=(18,10))
ax.scatter(df['club_join_year'],df['placement_offer_count'])
plt.show()

# %%
fig, ax=plt.subplots(figsize=(18,10))
ax.scatter(df['reading_score'],df['placement_offer_count'])
plt.show()

# %%
fig, ax=plt.subplots(figsize=(18,10))
ax.scatter(df['reading_score'],df['placement_score'])
plt.show()
